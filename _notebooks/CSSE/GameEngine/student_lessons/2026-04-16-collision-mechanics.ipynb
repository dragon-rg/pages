# %% [raw]
# ---
# layout: post
# courses: { csse: {week: 15} }
# title: Collision Mechanics
# description: Learn how collision mechanics work and how to use it.
# permalink: /doc/game/collision-mechanics/
# author: Vihaan Budhraja, Rigved Reddy
# ---

# %% [markdown]
# # Lesson on  Collision Mechanics in JavaScript
#
# ## What are Collision Mechanics?
#
# Collision mechanics control what happens when objects in a game collide, for example:
# - The player colliding with the guards in H.E.I.S.T.E.X.E
# -

# %% [markdown]
# ## How to integrate/use Collision Mechanics

# %% [markdown]
# ## Different uses of Collision Mechanics (examples)

# %% [markdown]
# ## How did we use Collision Mechanics in H.E.I.S.T.E.X.E?
