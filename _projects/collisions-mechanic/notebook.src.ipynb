# %% [raw]
# ---
# layout: post
# title: Collision mechanics
# description: Learn how collision mechanics work and how to use it.
# permalink: /collision_mechanics
# author: Vihaan Budhraja, Rigved Reddy
# ---

# %% [markdown]
# {TODO: add runner cell to display a simple level using enemy collisions}

# %% [markdown]
# ## Collision Mechanics with an Enemy
# Run the level above and move the player into the npc, and notice how the level restarts when you collide with the npc. This is done with the collision mechanics code from ```Enemy.js```. Using this file's logic, you can employ enemy collision mechanics in your own levels.

# %% [markdown]
# ## Enemy.js
# In our game engine, we can create enemies with consequential collision using the  ```Enemy.js``` JavaScript class.
#
# This class contains all the functions for the Enemy and can create consequences for player collisions. It extends the ```Character.js``` class.

# %%
# %%js
#
# import GameLevelCollisionMechanicsLessonLevel from '/_projects/collisions-mechanic/levels/GameLevelCollisionMechanicsLessonLevel';
# // GAME_RUNNER: CSSE Zone Game | hide_edit: true,  width: 100%, height: 500px
#
# export const gameLevelClasses = [GameLevelCollisionMechanicsLessonLevel];
# export { GameControl };
